# %% [markdown]
# # Pandas
# Es una librería de Python diseñada para trabajar con datos relacionados o etiquedatos de manera fácil e intuitiva. Principalmente se utiliza realizar análisis de datos.
#
# Pandas trabaja con diferentes tipos de datos como:
#
#
# *   Datos Tabulares ( Tabla SQL, Hoja de excel)
# *   Series de tiempo
# *   Data en forma de matrices
# *   Cualquier otra forma de data estadística.

# %% [markdown]
# Pandas cuenta con 2 estructuras de datos principales, las cuales son las **Series** y los **DataFrame**. Las Series son de 1 dimensión mientras que los Dataframes de 2 dimensiones.
#
#
# Recordar que Pandas está también construida en base a Numpy.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series
# Son un arreglo unidimensionales capaces de almacenar cualquier tipo de data (integers, strings, floating point numbers, Python objects, etc).
#
# Lo diferente de las series es que podemos especificar los indices.

# %%
#sintaxis
# pd.Series(data, index = index)
#np.nan es un 
#[ 20 , 12 , 14.5, '.', '*', '50000000']

serie = pd.Series([4,7,9,1,np.nan])
serie
# Out:
# 0    4.0
# 1    7.0
# 2    9.0
# 3    1.0
# 4    NaN
# dtype: float64

# %%
serie = pd.Series([4,7,9,1,np.nan], index = ["a","b","c","d","e"])
serie
# Out:
# a    4.0
# b    7.0
# c    9.0
# d    1.0
# e    NaN
# dtype: float64

# %%
# También se pueden instanciar de diccionarios
d = {
    "p" : 6,
    "a" : "hola",
     "b" : 7.0
}
pd.Series(d)
# Out:
# p       6
# a    hola
# b     7.0
# dtype: object

# %% [markdown]
# Las series actúan de manera muy parecida a un ndarray y es argumento válido para la mayoría de funciones de Numpy, sin embargo algunas operaciones afectan tanto al dato como a los índices.

# %%
print(serie)
print(serie[2:])
print(serie[[1,2]])
print(np.exp(serie))
# Out:
# a    4.0
# b    7.0
# c    9.0
# d    1.0
# e    NaN
# dtype: float64
# c    9.0
# d    1.0
# e    NaN
# dtype: float64
# b    7.0
# c    9.0
# dtype: float64
# a      54.598150
# b    1096.633158
# c    8103.083928
# d       2.718282
# e            NaN
# dtype: float64

# %%
# Las series también pueden ser accedidas como si fueran diccionarios
serie["a"]
# Out:
# 4.0

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
# un dataframe es una tabla
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    2 non-null      int64
#  1   col2    2 non-null      int64
# dtypes: int64(2)
# memory usage: 160.0 bytes

# %%
df.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %% [markdown]
# Es posible importar archivos .csv como un data frame

# %%
dfcsv = pd.read_csv('./Fullmetadata.csv')
print(dfcsv)
# Out:
#        player_id          player_name  games  time  goals        xG  assists  \
# 0           8865        Ollie Watkins      9   810      6  6.108615        1
# 1            675        Jack Grealish      9   810      5  3.136721        5
# 2            592         Ross Barkley      6   454      2  1.515623        1
# 3           1024         Tyrone Mings      9   810      2  1.362349        1
# 4           7726     Ezri Konsa Ngoyo      9   810      2  0.972794        0
# ...          ...                  ...    ...   ...    ...       ...      ...
# 18628       4267     Florian Hartherz     10   775      0  0.008183        2
# 18629       4268  Christian Strohdiek     22  1608      0  0.192864        0
# 18630       4311           Idir Ouali      6   296      0  0.608952        0
# 18631       4334         Mirnes Pepic      2    20      0  0.000000        0
# 18632       4363       Thomas Bertels      1     3      0  0.000000        0
#
#              xA  shots  key_passes  yellow_cards  red_cards position  \
# 0      1.294178     22          12             0          0        F
# 1      3.884479     26          26             2          0      F M
# 2      1.767355     17          15             0          0        M
# 3      0.068672      7           2             2          0        D
# 4      0.000000      7           0             0          0        D
# ...         ...    ...         ...           ...        ...      ...
# 18628  0.341444      1           5             1          1      D S
# 18629  0.095853      6           3             2          0      D S
# 18630  0.054503      4           1             1          0      M S
# 18631  0.000000      0           0             0          0        S
# 18632  0.000000      0           0             0          0        S
#
#          team_name  npg      npxG   xGChain  xGBuildup  year
# 0      Aston Villa    5  4.586278  6.570879   1.832243  2020
# 1      Aston Villa    5  3.136721  7.380403   2.577331  2020
# 2      Aston Villa    2  1.515623  3.546400   0.667209  2020
# 3      Aston Villa    2  1.362349  1.677874   1.661455  2020
# 4      Aston Villa    2  0.972794  0.627418   0.627418  2020
# ...            ...  ...       ...       ...        ...   ...
# 18628    Paderborn    0  0.008183  1.099364   0.908752  2014
# 18629    Paderborn    0  0.192864  1.002443   0.892720  2014
# 18630    Paderborn    0  0.608952  0.983527   0.374576  2014
# 18631    Paderborn    0  0.000000  0.000000   0.000000  2014
# 18632    Paderborn    0  0.000000  0.000000   0.000000  2014
#
# [18633 rows x 19 columns]

# %%
dfcsv.columns
# Out:
# Index(['player_id', 'player_name', 'games', 'time', 'goals', 'xG', 'assists',
#        'xA', 'shots', 'key_passes', 'yellow_cards', 'red_cards', 'position',
#        'team_name', 'npg', 'npxG', 'xGChain', 'xGBuildup', 'year'],
#       dtype='object')

# %%
dfcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18633 entries, 0 to 18632
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   player_id     18633 non-null  int64
#  1   player_name   18633 non-null  object
#  2   games         18633 non-null  int64
#  3   time          18633 non-null  int64
#  4   goals         18633 non-null  int64
#  5   xG            18633 non-null  float64
#  6   assists       18633 non-null  int64
#  7   xA            18633 non-null  float64
#  8   shots         18633 non-null  int64
#  9   key_passes    18633 non-null  int64
#  10  yellow_cards  18633 non-null  int64
#  11  red_cards     18633 non-null  int64
#  12  position      18633 non-null  object
#  13  team_name     18633 non-null  object
#  14  npg           18633 non-null  int64
#  15  npxG          18633 non-null  float64
#  16  xGChain       18633 non-null  float64
#  17  xGBuildup     18633 non-null  float64
#  18  year          18633 non-null  int64
# dtypes: float64(5), int64(11), object(3)
# memory usage: 2.7+ MB

# %%
# 5 primeras filas
dfcsv.head()
# Out:
#    player_id       player_name  games  time  goals        xG  assists  \
# 0       8865     Ollie Watkins      9   810      6  6.108615        1
# 1        675     Jack Grealish      9   810      5  3.136721        5
# 2        592      Ross Barkley      6   454      2  1.515623        1
# 3       1024      Tyrone Mings      9   810      2  1.362349        1
# 4       7726  Ezri Konsa Ngoyo      9   810      2  0.972794        0
#
#          xA  shots  key_passes  yellow_cards  red_cards position    team_name  \
# 0  1.294178     22          12             0          0        F  Aston Villa
# 1  3.884479     26          26             2          0      F M  Aston Villa
# 2  1.767355     17          15             0          0        M  Aston Villa
# 3  0.068672      7           2             2          0        D  Aston Villa
# 4  0.000000      7           0             0          0        D  Aston Villa
#
#    npg      npxG   xGChain  xGBuildup  year
# 0    5  4.586278  6.570879   1.832243  2020
# 1    5  3.136721  7.380403   2.577331  2020
# 2    2  1.515623  3.546400   0.667209  2020
# 3    2  1.362349  1.677874   1.661455  2020
# 4    2  0.972794  0.627418   0.627418  2020

# %%
# 5 últimas filas
dfcsv.tail()
# Out:
#        player_id          player_name  games  time  goals        xG  assists  \
# 18628       4267     Florian Hartherz     10   775      0  0.008183        2
# 18629       4268  Christian Strohdiek     22  1608      0  0.192864        0
# 18630       4311           Idir Ouali      6   296      0  0.608952        0
# 18631       4334         Mirnes Pepic      2    20      0  0.000000        0
# 18632       4363       Thomas Bertels      1     3      0  0.000000        0
#
#              xA  shots  key_passes  yellow_cards  red_cards position  \
# 18628  0.341444      1           5             1          1      D S
# 18629  0.095853      6           3             2          0      D S
# 18630  0.054503      4           1             1          0      M S
# 18631  0.000000      0           0             0          0        S
# 18632  0.000000      0           0             0          0        S
#
#        team_name  npg      npxG   xGChain  xGBuildup  year
# 18628  Paderborn    0  0.008183  1.099364   0.908752  2014
# 18629  Paderborn    0  0.192864  1.002443   0.892720  2014
# 18630  Paderborn    0  0.608952  0.983527   0.374576  2014
# 18631  Paderborn    0  0.000000  0.000000   0.000000  2014
# 18632  Paderborn    0  0.000000  0.000000   0.000000  2014

# %% [markdown]
# Ademas es posible seleccionar una columna como indice. En este caso seleccionamos la columna $player\_name$

# %%
# analogas
#print(dfcsv.time)
print(dfcsv["games"])
# Out:
# 0         9
# 1         9
# 2         6
# 3         9
# 4         9
#          ..
# 18628    10
# 18629    22
# 18630     6
# 18631     2
# 18632     1
# Name: games, Length: 18633, dtype: int64

# %%
# arreglo con valores
print(dfcsv["games"].values)
# Out:
# [9 9 6 ... 6 2 1]

# %%
dfcsv = pd.read_csv('./Fullmetadata.csv', index_col='player_name')
dfcsv
# Out:
#                      player_id  games  time  goals        xG  assists  \
# player_name
# Ollie Watkins             8865      9   810      6  6.108615        1
# Jack Grealish              675      9   810      5  3.136721        5
# Ross Barkley               592      6   454      2  1.515623        1
# Tyrone Mings              1024      9   810      2  1.362349        1
# Ezri Konsa Ngoyo          7726      9   810      2  0.972794        0
# ...                        ...    ...   ...    ...       ...      ...
# Florian Hartherz          4267     10   775      0  0.008183        2
# Christian Strohdiek       4268     22  1608      0  0.192864        0
# Idir Ouali                4311      6   296      0  0.608952        0
# Mirnes Pepic              4334      2    20      0  0.000000        0
# Thomas Bertels            4363      1     3      0  0.000000        0
#
#                            xA  shots  key_passes  yellow_cards  red_cards  \
# player_name
# Ollie Watkins        1.294178     22          12             0          0
# Jack Grealish        3.884479     26          26             2          0
# Ross Barkley         1.767355     17          15             0          0
# Tyrone Mings         0.068672      7           2             2          0
# Ezri Konsa Ngoyo     0.000000      7           0             0          0
# ...                       ...    ...         ...           ...        ...
# Florian Hartherz     0.341444      1           5             1          1
# Christian Strohdiek  0.095853      6           3             2          0
# Idir Ouali           0.054503      4           1             1          0
# Mirnes Pepic         0.000000      0           0             0          0
# Thomas Bertels       0.000000      0           0             0          0
#
#                     position    team_name  npg      npxG   xGChain  xGBuildup  \
# player_name
# Ollie Watkins              F  Aston Villa    5  4.586278  6.570879   1.832243
# Jack Grealish            F M  Aston Villa    5  3.136721  7.380403   2.577331
# Ross Barkley               M  Aston Villa    2  1.515623  3.546400   0.667209
# Tyrone Mings               D  Aston Villa    2  1.362349  1.677874   1.661455
# Ezri Konsa Ngoyo           D  Aston Villa    2  0.972794  0.627418   0.627418
# ...                      ...          ...  ...       ...       ...        ...
# Florian Hartherz         D S    Paderborn    0  0.008183  1.099364   0.908752
# Christian Strohdiek      D S    Paderborn    0  0.192864  1.002443   0.892720
# Idir Ouali               M S    Paderborn    0  0.608952  0.983527   0.374576
# Mirnes Pepic               S    Paderborn    0  0.000000  0.000000   0.000000
# Thomas Bertels             S    Paderborn    0  0.000000  0.000000   0.000000
#
#                      year
# player_name
# Ollie Watkins        2020
# Jack Grealish        2020
# Ross Barkley         2020
# Tyrone Mings         2020
# Ezri Konsa Ngoyo     2020
# ...                   ...
# Florian Hartherz     2014
# Christian Strohdiek  2014
# Idir Ouali           2014
# Mirnes Pepic         2014
# Thomas Bertels       2014
#
# [18633 rows x 18 columns]

# %% [markdown]
# Por ejemplo ahora seleccionaremos el $player\_id$ como índice

# %%
dfcsv = pd.read_csv('./data/Fullmetadata.csv', index_col='player_id')
dfcsv
# Out:
#                    player_name  games  time  goals        xG  assists  \
# player_id
# 8865             Ollie Watkins      9   810      6  6.108615        1
# 675              Jack Grealish      9   810      5  3.136721        5
# 592               Ross Barkley      6   454      2  1.515623        1
# 1024              Tyrone Mings      9   810      2  1.362349        1
# 7726          Ezri Konsa Ngoyo      9   810      2  0.972794        0
# ...                        ...    ...   ...    ...       ...      ...
# 4267          Florian Hartherz     10   775      0  0.008183        2
# 4268       Christian Strohdiek     22  1608      0  0.192864        0
# 4311                Idir Ouali      6   296      0  0.608952        0
# 4334              Mirnes Pepic      2    20      0  0.000000        0
# 4363            Thomas Bertels      1     3      0  0.000000        0
#
#                  xA  shots  key_passes  yellow_cards  red_cards position  \
# player_id
# 8865       1.294178     22          12             0          0        F
# 675        3.884479     26          26             2          0      F M
# 592        1.767355     17          15             0          0        M
# 1024       0.068672      7           2             2          0        D
# 7726       0.000000      7           0             0          0        D
# ...             ...    ...         ...           ...        ...      ...
# 4267       0.341444      1           5             1          1      D S
# 4268       0.095853      6           3             2          0      D S
# 4311       0.054503      4           1             1          0      M S
# 4334       0.000000      0           0             0          0        S
# 4363       0.000000      0           0             0          0        S
#
#              team_name  npg      npxG   xGChain  xGBuildup  year
# player_id
# 8865       Aston Villa    5  4.586278  6.570879   1.832243  2020
# 675        Aston Villa    5  3.136721  7.380403   2.577331  2020
# 592        Aston Villa    2  1.515623  3.546400   0.667209  2020
# 1024       Aston Villa    2  1.362349  1.677874   1.661455  2020
# 7726       Aston Villa    2  0.972794  0.627418   0.627418  2020
# ...                ...  ...       ...       ...        ...   ...
# 4267         Paderborn    0  0.008183  1.099364   0.908752  2014
# 4268         Paderborn    0  0.192864  1.002443   0.892720  2014
# 4311         Paderborn    0  0.608952  0.983527   0.374576  2014
# 4334         Paderborn    0  0.000000  0.000000   0.000000  2014
# 4363         Paderborn    0  0.000000  0.000000   0.000000  2014
#
# [18633 rows x 18 columns]

# %% [markdown]
# Un data frame es un objeto, como se vio en la clase de POO significa que cuenta con diversos metodos y atributos

# %%
# RETORNA LAS 5 PRIMERAS FILAS
dfcsv.head()
# Out:
#                 player_name  games  time  ...   xGChain  xGBuildup  year
# player_id                                 ...
# 8865          Ollie Watkins      9   810  ...  6.570879   1.832243  2020
# 675           Jack Grealish      9   810  ...  7.380403   2.577331  2020
# 592            Ross Barkley      6   454  ...  3.546400   0.667209  2020
# 1024           Tyrone Mings      9   810  ...  1.677874   1.661455  2020
# 7726       Ezri Konsa Ngoyo      9   810  ...  0.627418   0.627418  2020
#
# [5 rows x 18 columns]

# %%
# RETORNA LAS 5 ULTIMAS FILAS
dfcsv.tail()
# Out:
#                    player_name  games  time  ...   xGChain  xGBuildup  year
# player_id                                    ...
# 4267          Florian Hartherz     10   775  ...  1.099364   0.908752  2014
# 4268       Christian Strohdiek     22  1608  ...  1.002443   0.892720  2014
# 4311                Idir Ouali      6   296  ...  0.983527   0.374576  2014
# 4334              Mirnes Pepic      2    20  ...  0.000000   0.000000  2014
# 4363            Thomas Bertels      1     3  ...  0.000000   0.000000  2014
#
# [5 rows x 18 columns]

# %%
# RETORNA UNA FILA ALEATORIA
dfcsv.sample(10)
# Out:
#                player_name  games  time  goals        xG  assists        xA  \
# player_id
# 5196                Otegui      3    42      0  0.000000        0  0.000000
# 1953          Karim Laribi     11   481      0  0.669416        0  1.087740
# 1557        Carlos Carmona      8   466      0  0.059800        0  0.196788
# 1317          Andrés Tello     18   814      0  0.229302        0  0.558540
# 2164       Pablo Hernández      4   155      0  0.730133        0  0.092895
# 1306       Vincent Laurini     15  1078      0  0.049960        0  0.060422
# 3683        Ivan Cavaleiro     10   700      1  1.811039        0  0.374166
# 5985          Jeremy Grimm     23   779      1  0.469312        0  0.141456
# 3799           Wesley Said     34  2261      4  5.300151        1  2.453087
# 586            John Stones      3   270      0  0.036258        0  0.010289
#
#            shots  key_passes  yellow_cards  red_cards position  \
# player_id
# 5196           0           0             0          0        S
# 1953          10          11             0          0      M S
# 1557           1           3             2          1      M S
# 1317           8          11             6          0      M S
# 2164           5           1             0          0      M S
# 1306           2           2             1          0      D S
# 3683          13          10             1          0    F M S
# 5985          15           4             3          0      M S
# 3799          59          25             4          0  D F M S
# 586            1           1             0          0        D
#
#                  team_name  npg      npxG   xGChain  xGBuildup  year
# player_id
# 5196               Osasuna    0  0.000000  0.000000   0.000000  2016
# 1953              Sassuolo    0  0.669416  1.661837   0.932126  2015
# 1557              Atalanta    0  0.059800  1.708201   1.451613  2015
# 1317                Empoli    0  0.229302  1.657358   1.042832  2016
# 2164                 Leeds    0  0.730133  1.448521   0.658298  2020
# 1306                Empoli    0  0.049960  1.169131   1.058749  2014
# 3683                Fulham    0  0.288701  1.559360   1.092859  2020
# 5985            Strasbourg    1  0.469312  2.049396   1.656551  2017
# 3799                 Dijon    4  4.540055  7.262549   2.374438  2018
# 586        Manchester City    0  0.036258  0.520413   0.520413  2020

# %%
# RETORNA DATOS GENERALES DEL DATA FRAME
# FILAS Y COLUMNAS
print(dfcsv.shape)
# Out:
# (18633, 18)

# %%
# RETORNA EL TOTAL DE DATOS EN LA MATRIZ
print(dfcsv.size)
# Out:
# 335394

# %%
# RETORNA INFORMACION SOBRE LOS VALORES NO NULOS
# Y EL TIPO DE DATO DE LA COLUMNA
dfcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18633 entries, 8865 to 4363
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   player_name   18633 non-null  object
#  1   games         18633 non-null  int64
#  2   time          18633 non-null  int64
#  3   goals         18633 non-null  int64
#  4   xG            18633 non-null  float64
#  5   assists       18633 non-null  int64
#  6   xA            18633 non-null  float64
#  7   shots         18633 non-null  int64
#  8   key_passes    18633 non-null  int64
#  9   yellow_cards  18633 non-null  int64
#  10  red_cards     18633 non-null  int64
#  11  position      18633 non-null  object
#  12  team_name     18633 non-null  object
#  13  npg           18633 non-null  int64
#  14  npxG          18633 non-null  float64
#  15  xGChain       18633 non-null  float64
#  16  xGBuildup     18633 non-null  float64
#  17  year          18633 non-null  int64
# dtypes: float64(5), int64(10), object(3)
# memory usage: 2.7+ MB

# %%
# CALCULA ALGUNAS ESTADISTICAS DESCRIPTIVAS SOBRE EL CONJUNTO DE DATOS
dfcsv.describe()
# Out:
#               games          time  ...     xGBuildup          year
# count  18633.000000  18633.000000  ...  18633.000000  18633.000000
# mean      17.072291   1207.483282  ...      2.547434   2016.937691
# std       11.375527    975.753086  ...      2.955030      1.976606
# min        1.000000      1.000000  ...      0.000000   2014.000000
# 25%        7.000000    326.000000  ...      0.423074   2015.000000
# 50%       16.000000    976.000000  ...      1.623131   2017.000000
# 75%       27.000000   2004.000000  ...      3.599779   2019.000000
# max       38.000000   3420.000000  ...     28.058852   2020.000000
#
# [8 rows x 15 columns]

# %%
# ORDENA EL CONJUNTO DE DATOS RESPECTO A UNA COLUMNA
dfcsv.sort_values('player_name', ascending=False)
# Out:
#                player_name  games  time  goals        xG  assists        xA  \
# player_id
# 250           Ørjan Nyland      6   540      0  0.000000        0  0.000000
# 250           Ørjan Nyland     12  1021      0  0.000000        0  0.000000
# 250           Ørjan Nyland      7   536      0  0.000000        0  0.000000
# 2646        Özkan Yildirim      1    60      0  0.000000        0  0.000000
# 2646        Özkan Yildirim      1    13      0  0.083136        0  0.000000
# ...                    ...    ...   ...    ...       ...      ...       ...
# 534        Aaron Cresswell     20  1586      0  0.419239        1  0.937578
# 534        Aaron Cresswell     11   990      0  0.264341        3  1.606536
# 534        Aaron Cresswell     31  2739      3  1.032538        0  3.006657
# 7991        Aaron Connolly     24  1279      3  4.553526        1  0.562017
# 7991        Aaron Connolly      8   425      1  1.553084        1  0.132376
#
#            shots  key_passes  yellow_cards  red_cards position      team_name  \
# player_id
# 250            0           0             0          0       GK     Ingolstadt
# 250            0           0             0          0     GK S     Ingolstadt
# 250            0           0             0          0     GK S    Aston Villa
# 2646           0           0             0          0        M  Werder Bremen
# 2646           1           0             0          0        S  Werder Bremen
# ...          ...         ...           ...        ...      ...            ...
# 534           11          17             1          0      D S       West Ham
# 534            4          20             0          0        D       West Ham
# 534           18          26             7          0        D       West Ham
# 7991          36           6             0          0      F S       Brighton
# 7991           9           4             0          0      F S       Brighton
#
#            npg      npxG   xGChain  xGBuildup  year
# player_id
# 250          0  0.000000  0.167960   0.167960  2015
# 250          0  0.000000  0.593702   0.593702  2016
# 250          0  0.000000  0.194507   0.194507  2019
# 2646         0  0.000000  0.013800   0.013800  2014
# 2646         0  0.083136  0.083136   0.000000  2015
# ...        ...       ...       ...        ...   ...
# 534          0  0.419239  2.039328   1.581602  2018
# 534          0  0.264341  3.518969   2.893820  2020
# 534          3  1.032538  6.834942   4.891464  2019
# 7991         3  4.553526  4.356782   0.354199  2019
# 7991         1  1.553084  1.683810   0.031006  2020
#
# [18633 rows x 18 columns]

# %% [markdown]
# Ademas de los metodos que nos sirven para mostrar informacion de la data. Se puede hacer filtrados y seleccionar subconjuntos dentro de los dataframes.

# %%
# tarea
dfcsv["player_name"].unique()
# Out:
# array(['Ollie Watkins', 'Jack Grealish', 'Ross Barkley', ...,
#        'Idir Ouali', 'Mirnes Pepic', 'Thomas Bertels'], dtype=object)

# %%
# SELECCIONA LOS VALORES DE UNA COLUMNA DE MANERA UNICA
dfcsv['team_name'].unique()
# Out:
# array(['Aston Villa', 'Everton', 'Southampton', 'Leicester',
#        'West Bromwich Albion', 'Crystal Palace', 'Chelsea', 'West Ham',
#        'Tottenham', 'Arsenal', 'Newcastle United', 'Liverpool',
#        'Manchester City', 'Manchester United', 'Burnley', 'Brighton',
#        'Fulham', 'Wolverhampton Wanderers', 'Sheffield United', 'Leeds',
#        'Sevilla', 'Real Sociedad', 'Getafe', 'Atletico Madrid',
#        'Valencia', 'Athletic Club', 'Barcelona', 'Real Madrid', 'Levante',
#        'Celta Vigo', 'Real Betis', 'Villarreal', 'Granada', 'Eibar',
#        'Osasuna', 'Alaves', 'Elche', 'Real Valladolid', 'SD Huesca',
#        'Cadiz', 'Verona', 'Roma', 'Lazio', 'Bologna', 'Juventus',
#        'Udinese', 'Genoa', 'Sampdoria', 'Sassuolo', 'Napoli', 'Inter',
#        'Atalanta', 'Fiorentina', 'AC Milan', 'Torino', 'Crotone',
#        'Cagliari', 'Benevento', 'Parma Calcio 1913', 'Spezia', 'Lille',
#        'Paris Saint Germain', 'Rennes', 'Marseille', 'Montpellier',
#        'Angers', 'Nantes', 'Nice', 'Monaco', 'Saint-Etienne', 'Bordeaux',
#        'Reims', 'Lyon', 'Lorient', 'Metz', 'Dijon', 'Lens', 'Strasbourg',
#        'Nimes', 'Brest', 'Bayern Munich', 'Bayer Leverkusen',
#        'Hoffenheim', 'Augsburg', 'Hertha Berlin', 'Werder Bremen',
#        'Schalke 04', 'Mainz 05', 'Borussia Dortmund',
#        'Borussia M.Gladbach', 'Wolfsburg', 'Eintracht Frankfurt',
#        'VfB Stuttgart', 'FC Cologne', 'Freiburg',
#        'RasenBallsport Leipzig', 'Union Berlin', 'Arminia Bielefeld',
#        'Bournemouth', 'Norwich', 'Watford', 'Espanyol', 'Leganes',
#        'Mallorca', 'SPAL 2013', 'Brescia', 'Lecce', 'Toulouse', 'Amiens',
#        'Paderborn', 'Fortuna Duesseldorf', 'Huddersfield', 'Cardiff',
#        'Rayo Vallecano', 'Girona', 'Empoli', 'Chievo', 'Frosinone',
#        'Caen', 'Guingamp', 'Hannover 96', 'Nuernberg', 'Swansea', 'Stoke',
#        'Malaga', 'Deportivo La Coruna', 'Las Palmas', 'Troyes',
#        'Hamburger SV', 'Sunderland', 'Hull', 'Middlesbrough',
#        'Sporting Gijon', 'Palermo', 'Pescara', 'SC Bastia', 'Nancy',
#        'Ingolstadt', 'Darmstadt', 'Carpi', 'GFC Ajaccio',
#        'Queens Park Rangers', 'Cordoba', 'Almeria', 'Cesena', 'Parma',
#        'Evian Thonon Gaillard'], dtype=object)

# %%
(dfcsv.goals==4)
# Out:
# player_id
# 8865    False
# 675     False
# 592     False
# 1024    False
# 7726    False
#         ...
# 4267    False
# 4268    False
# 4311    False
# 4334    False
# 4363    False
# Name: goals, Length: 18633, dtype: bool

# %%
# UN OPERADOR BOOLEANO CON UNA COLUMNA DEL DATA FRAME RETORNARA TODAS LAS FILAS
# QUE SATISFACEN LA EXPRESION BOOLEANA Y LAS MAPEA COMO False o True
seleccionados = (dfcsv.goals==4)
seleccionados
# Out:
# player_id
# 8865    False
# 675     False
# 592     False
# 1024    False
# 7726    False
#         ...
# 4267    False
# 4268    False
# 4311    False
# 4334    False
# 4363    False
# Name: goals, Length: 18633, dtype: bool

# %%
# SELECCIONA TODAS LAS FILAS MAPEADAS EN LA CELDA ANTERIOR COMO TRUE
dfcsv[seleccionados]
# Out:
#                   player_name  games  time  ...    xGChain  xGBuildup  year
# player_id                                   ...
# 843         James Ward-Prowse     11   990  ...   2.517873   2.041089  2020
# 65                Timo Werner     11   943  ...   7.629157   2.278263  2020
# 935                Kurt Zouma     10   900  ...   1.932639   1.932639  2020
# 1776             Jarrod Bowen     11   921  ...   5.957856   2.169729  2020
# 838                Sadio Mané     10   825  ...   7.383594   1.892225  2020
# ...                       ...    ...   ...  ...        ...        ...   ...
# 81            Jonathan Schmid     33  2826  ...   9.149545   3.101696  2014
# 194             Admir Mehmedi     28  2254  ...   8.266530   4.162098  2014
# 4246              Mike Frantz     25  1191  ...   5.093012   1.453917  2014
# 62                 Lukas Rupp     31  2010  ...   6.888414   2.880639  2014
# 4296       Moritz Stoppelkamp     27  2182  ...  10.249944   2.722048  2014
#
# [632 rows x 18 columns]

# %%
#from        where              select
otrodf = dfcsv.loc[dfcsv["goals"] == 4 , ["games", "goals"]]
otrodf
# Out:
#            games  goals
# player_id
# 843           11      4
# 65            11      4
# 935           10      4
# 1776          11      4
# 838           10      4
# ...          ...    ...
# 81            33      4
# 194           28      4
# 4246          25      4
# 62            31      4
# 4296          27      4
#
# [632 rows x 2 columns]

# %%
dfcsv
# Out:
#                    player_name  games  time  goals        xG  assists  \
# player_id
# 8865             Ollie Watkins      9   810      6  6.108615        1
# 675              Jack Grealish      9   810      5  3.136721        5
# 592               Ross Barkley      6   454      2  1.515623        1
# 1024              Tyrone Mings      9   810      2  1.362349        1
# 7726          Ezri Konsa Ngoyo      9   810      2  0.972794        0
# ...                        ...    ...   ...    ...       ...      ...
# 4267          Florian Hartherz     10   775      0  0.008183        2
# 4268       Christian Strohdiek     22  1608      0  0.192864        0
# 4311                Idir Ouali      6   296      0  0.608952        0
# 4334              Mirnes Pepic      2    20      0  0.000000        0
# 4363            Thomas Bertels      1     3      0  0.000000        0
#
#                  xA  shots  key_passes  yellow_cards  red_cards position  \
# player_id
# 8865       1.294178     22          12             0          0        F
# 675        3.884479     26          26             2          0      F M
# 592        1.767355     17          15             0          0        M
# 1024       0.068672      7           2             2          0        D
# 7726       0.000000      7           0             0          0        D
# ...             ...    ...         ...           ...        ...      ...
# 4267       0.341444      1           5             1          1      D S
# 4268       0.095853      6           3             2          0      D S
# 4311       0.054503      4           1             1          0      M S
# 4334       0.000000      0           0             0          0        S
# 4363       0.000000      0           0             0          0        S
#
#              team_name  npg      npxG   xGChain  xGBuildup  year
# player_id
# 8865       Aston Villa    5  4.586278  6.570879   1.832243  2020
# 675        Aston Villa    5  3.136721  7.380403   2.577331  2020
# 592        Aston Villa    2  1.515623  3.546400   0.667209  2020
# 1024       Aston Villa    2  1.362349  1.677874   1.661455  2020
# 7726       Aston Villa    2  0.972794  0.627418   0.627418  2020
# ...                ...  ...       ...       ...        ...   ...
# 4267         Paderborn    0  0.008183  1.099364   0.908752  2014
# 4268         Paderborn    0  0.192864  1.002443   0.892720  2014
# 4311         Paderborn    0  0.608952  0.983527   0.374576  2014
# 4334         Paderborn    0  0.000000  0.000000   0.000000  2014
# 4363         Paderborn    0  0.000000  0.000000   0.000000  2014
#
# [18633 rows x 18 columns]

# %% [markdown]
# Es importante notar que el filtrado anterior se puede extender a cualquier función booleana incluso funciones definidas por nosotros mismos.

# %%
def es_cuatro(n):
  return n==4

#REALIZA EL MAPEO A CADA FILA Y SE GUARDA EN seleccionadosPorFuncion
seleccionadosPorFuncion = es_cuatro(dfcsv.goals)

dfcsv[seleccionadosPorFuncion]
# Out:
#                   player_name  games  time  goals        xG  assists  \
# player_id
# 843         James Ward-Prowse     11   990      4  0.714341        3
# 65                Timo Werner     11   943      4  5.500642        3
# 935                Kurt Zouma     10   900      4  0.743740        0
# 1776             Jarrod Bowen     11   921      4  3.402587        1
# 838                Sadio Mané     10   825      4  4.921544        1
# ...                       ...    ...   ...    ...       ...      ...
# 81            Jonathan Schmid     33  2826      4  5.148357        8
# 194             Admir Mehmedi     28  2254      4  5.144821        1
# 4246              Mike Frantz     25  1191      4  3.493235        1
# 62                 Lukas Rupp     31  2010      4  2.587367        1
# 4296       Moritz Stoppelkamp     27  2182      4  5.591954        2
#
#                  xA  shots  key_passes  yellow_cards  red_cards position  \
# player_id
# 843        1.256335     10          18             2          0        M
# 65         2.101302     28          10             0          0      F M
# 935        0.018804      8           1             1          0        D
# 1776       1.321204     27          10             0          0      F M
# 838        1.395934     32          16             2          0    F M S
# ...             ...    ...         ...           ...        ...      ...
# 81         6.221347     60          64             2          0    F M S
# 194        1.570053     51          29             3          0    F M S
# 4246       1.234888     23          12             3          0    F M S
# 62         2.207702     32          30             3          0    F M S
# 4296       4.070897     66          43             5          0    F M S
#
#              team_name  npg      npxG    xGChain  xGBuildup  year
# player_id
# 843        Southampton    4  0.714341   2.517873   2.041089  2020
# 65             Chelsea    4  5.500642   7.629157   2.278263  2020
# 935            Chelsea    4  0.743740   1.932639   1.932639  2020
# 1776          West Ham    4  3.402587   5.957856   2.169729  2020
# 838          Liverpool    4  4.921544   7.383594   1.892225  2020
# ...                ...  ...       ...        ...        ...   ...
# 81            Freiburg    4  5.148357   9.149545   3.101696  2014
# 194           Freiburg    4  4.387044   8.266530   4.162098  2014
# 4246          Freiburg    4  3.493235   5.093012   1.453917  2014
# 62           Paderborn    4  2.587367   6.888414   2.880639  2014
# 4296         Paderborn    4  5.591954  10.249944   2.722048  2014
#
# [632 rows x 18 columns]

# %% [markdown]
# Sin embargo, la sintaxis que proporciona pandas es mucho mas intuitiva podiendo realizar lo anterior de la siguiente manera:

# %%
df[df.goals==4]
# Out:
#        player_id         player_name  games  ...    xGChain  xGBuildup  year
# 44           843   James Ward-Prowse     11  ...   2.517873   2.041089  2020
# 128           65         Timo Werner     11  ...   7.629157   2.278263  2020
# 129          935          Kurt Zouma     10  ...   1.932639   1.932639  2020
# 154         1776        Jarrod Bowen     11  ...   5.957856   2.169729  2020
# 241          838          Sadio Mané     10  ...   7.383594   1.892225  2020
# ...          ...                 ...    ...  ...        ...        ...   ...
# 18584         81     Jonathan Schmid     33  ...   9.149545   3.101696  2014
# 18585        194       Admir Mehmedi     28  ...   8.266530   4.162098  2014
# 18586       4246         Mike Frantz     25  ...   5.093012   1.453917  2014
# 18610         62          Lukas Rupp     31  ...   6.888414   2.880639  2014
# 18611       4296  Moritz Stoppelkamp     27  ...  10.249944   2.722048  2014
#
# [632 rows x 19 columns]

# %% [markdown]
# Tambien se puede utilizar el metodo $.query()$

# %%
dfcsv.query('goals == 4')
# Out:
#                   player_name  games  time  ...    xGChain  xGBuildup  year
# player_id                                   ...
# 843         James Ward-Prowse     11   990  ...   2.517873   2.041089  2020
# 65                Timo Werner     11   943  ...   7.629157   2.278263  2020
# 935                Kurt Zouma     10   900  ...   1.932639   1.932639  2020
# 1776             Jarrod Bowen     11   921  ...   5.957856   2.169729  2020
# 838                Sadio Mané     10   825  ...   7.383594   1.892225  2020
# ...                       ...    ...   ...  ...        ...        ...   ...
# 81            Jonathan Schmid     33  2826  ...   9.149545   3.101696  2014
# 194             Admir Mehmedi     28  2254  ...   8.266530   4.162098  2014
# 4246              Mike Frantz     25  1191  ...   5.093012   1.453917  2014
# 62                 Lukas Rupp     31  2010  ...   6.888414   2.880639  2014
# 4296       Moritz Stoppelkamp     27  2182  ...  10.249944   2.722048  2014
#
# [632 rows x 18 columns]

# %% [markdown]
# Se puede utilizar el metodo $isin$ para seleccionar las filas que estan dentro de un conjunto de datos.

# %%
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
players = ['Cristiano Ronaldo', 'Lionel Messi', 'Luis Suárez']
dfcsv.player_name.isin(players)
# Out:
# player_id
# 8865    False
# 675     False
# 592     False
# 1024    False
# 7726    False
#         ...
# 4267    False
# 4268    False
# 4311    False
# 4334    False
# 4363    False
# Name: player_name, Length: 18633, dtype: bool

# %%
players = ['Cristiano Ronaldo', 'Lionel Messi', 'Luis Suárez']
top_players = dfcsv[ (dfcsv.player_name.isin(players))]

top_players
# Out:
#                  player_name  games  time  goals         xG  assists  \
# player_id
# 2098             Luis Suárez      7   442      5   3.594253        1
# 2097            Lionel Messi     10   851      4   6.659800        0
# 8978             Luis Suárez      8   378      2   0.945550        0
# 2371       Cristiano Ronaldo      6   470      8   5.799580        1
# 2097            Lionel Messi     33  2876     25  20.849667       20
# 2098             Luis Suárez     28  1989     16  13.913964        8
# 2371       Cristiano Ronaldo     33  2920     31  29.431679        5
# 2097            Lionel Messi     34  2704     36  25.997169       13
# 2098             Luis Suárez     33  2832     21  24.394436        6
# 2371       Cristiano Ronaldo     31  2692     21  23.324040        8
# 2097            Lionel Messi     36  2995     34  28.946281       12
# 2098             Luis Suárez     33  2902     25  25.367980       12
# 2371       Cristiano Ronaldo     27  2304     26  26.999304        5
# 2097            Lionel Messi     34  2832     37  26.885174        9
# 2098             Luis Suárez     35  2870     29  23.780646       13
# 2371       Cristiano Ronaldo     29  2546     25  25.413738        6
# 2098             Luis Suárez     35  3150     40  35.833731       16
# 2097            Lionel Messi     33  2726     26  27.101910       16
# 2371       Cristiano Ronaldo     36  3186     35  35.589006       11
# 2097            Lionel Messi     38  3374     43  35.891764       18
# 2098             Luis Suárez     27  2182     16  14.542310       14
# 2371       Cristiano Ronaldo     35  3103     48  39.308761       16
#
#                   xA  shots  key_passes  yellow_cards  red_cards position  \
# player_id
# 2098        0.601812     27           6             2          0      F S
# 2097        2.558279     49          22             3          0    F M S
# 8978        0.234944      8           5             2          0    F M S
# 2371        0.725525     29           7             0          0      F S
# 2097       16.593363    159          88             4          0    F M S
# 2098        3.169745     79          26             4          0      F S
# 2371        6.067226    208          51             3          0        F
# 2097       15.335166    170          93             3          0      F S
# 2098        7.323391    112          47             5          0      F S
# 2371        5.193874    175          48             3          0    F M S
# 2097       15.100406    196          87             3          0    F M S
# 2098       11.144683    121          56             9          0      F S
# 2371        5.524842    178          40             1          0        F
# 2097       13.955131    179          79             6          0    F M S
# 2098       11.039603    120          62             8          0      F S
# 2371        4.591036    162          31             4          0      F M
# 2098       13.275963    137          56             6          0        F
# 2097       15.871278    158          77             3          0    F M S
# 2371        8.606404    227          51             3          0      F M
# 2097       17.611956    187          95             4          0      F S
# 2098       13.520658     75          60             4          0      F S
# 2371       13.600642    225          76             5          1      F M
#
#                  team_name  npg       npxG    xGChain  xGBuildup  year
# player_id
# 2098       Atletico Madrid    5   3.594253   4.075823   0.158470  2020
# 2097             Barcelona    2   5.173245   8.966301   5.945141  2020
# 8978               Granada    2   0.945550   1.863301   0.682806  2020
# 2371              Juventus    6   4.276982   5.001183   1.742834  2020
# 2097             Barcelona   20  17.133279  34.923467  13.537658  2019
# 2098             Barcelona   15  13.170687  18.988987   4.466442  2019
# 2371              Juventus   19  19.534956  26.553609   7.224642  2019
# 2097             Barcelona   32  22.280909  38.459877  10.698799  2018
# 2098             Barcelona   17  21.421453  36.808274  12.378092  2018
# 2371              Juventus   16  18.756287  21.854170   7.177339  2018
# 2097             Barcelona   32  25.973170  48.180634  21.634404  2017
# 2098             Barcelona   24  24.624702  38.566809   8.494505  2017
# 2371           Real Madrid   23  24.026193  31.623837   9.471853  2017
# 2097             Barcelona   31  21.682231  42.525045  18.133512  2016
# 2098             Barcelona   29  23.780646  39.092286   9.213265  2016
# 2371           Real Madrid   19  19.467645  29.574578   8.661095  2016
# 2098             Barcelona   37  32.117727  44.871907   9.114416  2015
# 2097             Barcelona   23  21.899351  41.996866  15.196364  2015
# 2371           Real Madrid   29  28.899508  40.818028   9.863005  2015
# 2097             Barcelona   38  31.432098  54.753610  19.756724  2014
# 2098             Barcelona   16  14.542310  28.306160   6.215008  2014
# 2371           Real Madrid   38  30.389686  43.608020   7.520237  2014

# %% [markdown]
# Usando la funcion $loc()$ podemos seleccionar filas o columnas siguiendo una etiqueta o tambien siguiendo una condicion

# %%
dfcsv.loc[dfcsv.goals == 4]
# Out:
#                   player_name  games  time  ...    xGChain  xGBuildup  year
# player_id                                   ...
# 843         James Ward-Prowse     11   990  ...   2.517873   2.041089  2020
# 65                Timo Werner     11   943  ...   7.629157   2.278263  2020
# 935                Kurt Zouma     10   900  ...   1.932639   1.932639  2020
# 1776             Jarrod Bowen     11   921  ...   5.957856   2.169729  2020
# 838                Sadio Mané     10   825  ...   7.383594   1.892225  2020
# ...                       ...    ...   ...  ...        ...        ...   ...
# 81            Jonathan Schmid     33  2826  ...   9.149545   3.101696  2014
# 194             Admir Mehmedi     28  2254  ...   8.266530   4.162098  2014
# 4246              Mike Frantz     25  1191  ...   5.093012   1.453917  2014
# 62                 Lukas Rupp     31  2010  ...   6.888414   2.880639  2014
# 4296       Moritz Stoppelkamp     27  2182  ...  10.249944   2.722048  2014
#
# [632 rows x 18 columns]
